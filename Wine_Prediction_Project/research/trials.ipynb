# %%
print("Hello Rahul, How are you?")
# Out:
# Hello Rahul, How are you?

# %%
import yaml

yaml_file_path = "test.yaml"

# Open the YAML file and load its contents
with open(yaml_file_path, 'r') as yaml_file:
    data = yaml.safe_load(yaml_file)


print(data)
print(type(data))
# Out:
# {'user': 'Rahul_Hasan', 'email': 'rahulhasanhelp@gmail.com'}
# <class 'dict'>

# %%
data["user"]
# Out:
# 'Rahul_Hasan'

# %%
data["email"]
# Out:
# 'rahulhasanhelp@gmail.com'

# %%
from box import ConfigBox
d = ConfigBox(data)
d
# Out:
# ConfigBox({'user': 'Rahul_Hasan', 'email': 'rahulhasanhelp@gmail.com'})

# %%
def get_product(x:int, y:int):
    return x*y

# %%
get_product(2, 3)
# Out:
# 6

# %%
get_product(2, "3")
# Out:
# '33'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x:int, y:int):
    return x*y

# %%
get_product(2, 3)
# Out:
# 6

# %%
get_product(2, "3")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 get_product(2, "3")
#
# File c:\Users\HP\anaconda3\envs\mlops-3.11-06062026\Lib\site-packages\ensure\main.py:803, in WrappedFunction.__call__(self, *args, **kwargs)
#     798     if not isinstance(value, templ):
#     799         msg = (
#     800             "Argument {arg} of type {valt} to {f} "
#     801             "does not match annotation type {t}"
#     802         )
# --> 803         raise EnsureError(msg.format(
#     804             arg=arg, f=self.f, t=templ, valt=type(value)
#     805         ))
#     807 return self.f(*args, **kwargs)
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x000001CF828E5F80> does not match annotation type <class 'int'>

# %%
print("Hello Rahul, How are you today?")
# Out:
# Hello Rahul, How are you today?
